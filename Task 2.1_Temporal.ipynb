# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Boston_Data_Clean.csv", index_col=0, low_memory=False)
data
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                   start_time             end_time  start_station_id  \
# 0        2017-01-01 00:06:58  2017-01-01 00:12:49                67
# 1        2017-01-01 00:13:16  2017-01-01 00:28:07                36
# 2        2017-01-01 00:16:17  2017-01-01 00:44:10                36
# 3        2017-01-01 00:21:22  2017-01-01 00:33:50                46
# 4        2017-01-01 00:30:06  2017-01-01 00:40:28                10
# ...                      ...                  ...               ...
# 1313769  2017-12-31 23:46:18  2017-12-31 23:50:27               117
# 1313770  2017-12-29 16:11:56  2017-12-29 16:16:18                54
# 1313771  2017-12-30 08:09:44  2017-12-30 08:26:08                54
# 1313772  2017-12-30 12:20:01  2017-12-30 12:49:12                54
# 1313773  2017-12-30 18:27:39  2017-12-30 18:53:54                54
#
#          end_station_id                        start_station_name  \
# 0                   139              MIT at Mass Ave / Amherst St
# 1                    10  Boston Public Library - 700 Boylston St.
# 2                     9  Boston Public Library - 700 Boylston St.
# 3                    19                   Christian Science Plaza
# 4                     8             B.U. Central - 725 Comm. Ave.
# ...                 ...                                       ...
# 1313769             141                      Binney St / Sixth St
# 1313770              42                     Tremont St at West St
# 1313771              58                     Tremont St at West St
# 1313772              46                     Tremont St at West St
# 1313773              21                     Tremont St at West St
#
#                                           end_station_name  bike_id  \
# 0                                                Dana Park      644
# 1                            B.U. Central - 725 Comm. Ave.      230
# 2                            Agganis Arena - 925 Comm Ave.      980
# 3                                  Buswell St. at Park Dr.     1834
# 4            Union Square - Brighton Ave. at Cambridge St.      230
# ...                                                    ...      ...
# 1313769                                     Kendall Street     1846
# 1313770  Boylston St at Arlington St TEMPORARY WINTER L...        2
# 1313771                          Beacon St at Arlington St     1534
# 1313772  Christian Science Plaza - Massachusetts Ave at...     1978
# 1313773                   Prudential Center - Belvedere St       15
#
#           user_type
# 0        Subscriber
# 1        Subscriber
# 2          Customer
# 3        Subscriber
# 4        Subscriber
# ...             ...
# 1313769  Subscriber
# 1313770  Subscriber
# 1313771  Subscriber
# 1313772  Subscriber
# 1313773  Subscriber
#
# [1313757 rows x 8 columns]

# %%
data = data.drop(['start_station_id'], axis=1)
data = data.drop(['end_station_id'], axis=1)
data = data.drop(['start_station_name'], axis=1)
data = data.drop(['end_station_name'], axis=1)
data = data.drop(['bike_id'], axis=1)
data = data.drop(['user_type'], axis=1)
data
# Out:
#                   start_time             end_time
# 0        2017-01-01 00:06:58  2017-01-01 00:12:49
# 1        2017-01-01 00:13:16  2017-01-01 00:28:07
# 2        2017-01-01 00:16:17  2017-01-01 00:44:10
# 3        2017-01-01 00:21:22  2017-01-01 00:33:50
# 4        2017-01-01 00:30:06  2017-01-01 00:40:28
# ...                      ...                  ...
# 1313769  2017-12-31 23:46:18  2017-12-31 23:50:27
# 1313770  2017-12-29 16:11:56  2017-12-29 16:16:18
# 1313771  2017-12-30 08:09:44  2017-12-30 08:26:08
# 1313772  2017-12-30 12:20:01  2017-12-30 12:49:12
# 1313773  2017-12-30 18:27:39  2017-12-30 18:53:54
#
# [1313757 rows x 2 columns]

# %%
data['start_time'] = pd.to_datetime(data['start_time'], errors='coerce')
data['end_time'] = pd.to_datetime(data['end_time'], errors='coerce')

data['dayofweek_start'] = data.start_time.dt.dayofweek
data['dayofweek_end'] = data.end_time.dt.dayofweek

data['month_start'] = data.start_time.dt.month
data['month_end'] = data.end_time.dt.month

data['time_start'] = data.start_time.dt.time
data['time_end'] = data.end_time.dt.time

data['start_hour'] = data.start_time.dt.hour
data['duration'] = data.end_time - data.start_time

data['duration_minutes'] = data.duration.apply(
    lambda x: pd.Timedelta(x).total_seconds()/60
)
data
# Out:
#                  start_time            end_time  dayofweek_start  \
# 0       2017-01-01 00:06:58 2017-01-01 00:12:49                6
# 1       2017-01-01 00:13:16 2017-01-01 00:28:07                6
# 2       2017-01-01 00:16:17 2017-01-01 00:44:10                6
# 3       2017-01-01 00:21:22 2017-01-01 00:33:50                6
# 4       2017-01-01 00:30:06 2017-01-01 00:40:28                6
# ...                     ...                 ...              ...
# 1313769 2017-12-31 23:46:18 2017-12-31 23:50:27                6
# 1313770 2017-12-29 16:11:56 2017-12-29 16:16:18                4
# 1313771 2017-12-30 08:09:44 2017-12-30 08:26:08                5
# 1313772 2017-12-30 12:20:01 2017-12-30 12:49:12                5
# 1313773 2017-12-30 18:27:39 2017-12-30 18:53:54                5
#
#          dayofweek_end  month_start  month_end time_start  time_end  \
# 0                    6            1          1   00:06:58  00:12:49
# 1                    6            1          1   00:13:16  00:28:07
# 2                    6            1          1   00:16:17  00:44:10
# 3                    6            1          1   00:21:22  00:33:50
# 4                    6            1          1   00:30:06  00:40:28
# ...                ...          ...        ...        ...       ...
# 1313769              6           12         12   23:46:18  23:50:27
# 1313770              4           12         12   16:11:56  16:16:18
# 1313771              5           12         12   08:09:44  08:26:08
# 1313772              5           12         12   12:20:01  12:49:12
# 1313773              5           12         12   18:27:39  18:53:54
#
#          start_hour        duration  duration_minutes
# 0                 0 0 days 00:05:51          5.850000
# 1                 0 0 days 00:14:51         14.850000
# 2                 0 0 days 00:27:53         27.883333
# 3                 0 0 days 00:12:28         12.466667
# 4                 0 0 days 00:10:22         10.366667
# ...             ...             ...               ...
# 1313769          23 0 days 00:04:09          4.150000
# 1313770          16 0 days 00:04:22          4.366667
# 1313771           8 0 days 00:16:24         16.400000
# 1313772          12 0 days 00:29:11         29.183333
# 1313773          18 0 days 00:26:15         26.250000
#
# [1313757 rows x 11 columns]

# %%
data_start_hours = data.drop(['dayofweek_start'], axis=1)
data_start_hours = data_start_hours.drop(['dayofweek_end'], axis=1)

# %%
mappingDay = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}
data = data.replace({"dayofweek_start": mappingDay})
data = data.replace({"dayofweek_end": mappingDay})
day_order = ["Monday", "Thursday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

mapping_Month = {1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr", 5: "May", 6: "Jun", 7: "Jul", 8: "Aug", 9: "Sep", 10: "Oct", 11: "Nov", 12: "Dec"}
data = data.replace({"month_start": mapping_Month})
data = data.replace({"month_end": mapping_Month})
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
# 5                    7148.0  17.698547  164.159745  1.016667  5.862500
# 6                   25992.0  13.508035  105.262185  1.016667  5.916667
# 7                   72127.0  13.989914  100.270087  1.016667  6.716667
# 8                  124246.0  13.535356   75.519586  1.016667  6.666667
# 9                   75247.0  14.721699   54.245663  1.016667  6.100000
# 10                  55812.0  20.527029  315.188151  1.016667  6.250000
# 11                  61344.0  23.278946  238.333509  1.016667  6.433333
# 12                  72229.0  20.187129  115.387685  1.016667  6.183333
# 13                  71485.0  22.227490  240.110192  1.016667  6.550000
# 14                  71017.0  21.033697  131.312534  1.016667  6.733333
# 15                  78971.0  22.117999  229.295362  1.016667  7.016667
# 16                 113276.0  18.486237  134.656315  1.016667  7.150000
# 17                 148198.0  18.615982  270.316970  1.016667  7.133333
# 18                 108229.0  19.013143  261.977015  1.016667  6.733333
# 19                  73653.0  18.422383  281.471960  1.016667  6.400000
# 20                  50842.0  19.020651  219.302315  1.016667  6.150000
# 21                  35797.0  17.400539  180.145501  1.016667  6.116667
# 22                  26885.0  20.469205  198.007211  1.016667  6.200000
# 23                  17489.0  23.970860  302.030805  1.050000  5.916667
#
#
#                   50%        75%           max
# start_hour
# 0            9.633333  16.400000  24559.466667
# 1           10.733333  18.633333  49603.283333
# 2           10.950000  18.766667  49301.750000
# 3           10.683333  20.300000   7521.416667
# 4           13.000000  19.120833  13537.466667
# 5            9.050000  14.533333   8176.883333
# 6            9.416667  14.450000  14397.516667
# 7           10.266667  15.883333  16030.233333
# 8           10.433333  15.850000  17261.800000
# 9            9.816667  15.716667   5850.550000
# 10          10.666667  18.450000  69640.350000
# 11          11.216667  19.820833  27974.300000
# 12          10.883333  19.583333  12920.700000
# 13          11.500000  20.533333  47533.333333
# 14          12.050000  21.016667  20046.383333
# 15          12.200000  20.366667  37498.000000
# 16          11.633333  18.550000  16061.716667
# 17          11.600000  18.300000  61276.800000
# 18          11.350000  18.216667  43519.900000
# 19          10.633333  17.400000  49022.800000
# 20          10.133333  16.750000  28793.633333
# 21          10.150000  16.816667  22586.333333
# 22          10.316667  17.150000  20577.616667
# 23          10.016667  16.900000  24107.716667
#
# [24 rows x 32 columns]

# %%
grouped_by_start_hour_graph = data_start_hours.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_by_start_hour_graph.index, grouped_by_start_hour_graph["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# # Test of different special days, like holidays
# Open question that remains is the validity.
# Also the number of rides varies quite a lot.
#
# Holidays:
# - New Year's Day: Jan 1
# - Independence Day: July 4
# - Labor Day: 1st Monday in September
# - Thanksgiving Day: 4th Thursday in November
# - Christmas Day: December 25

# %% [markdown]
# # Holidays
# ## New Year's Day

# %%
data_new_year = data[data['start_time'].dt.date.astype(str) == '2017-01-01']
#data_new_year

# %%
grouped_new_year = data_new_year.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_new_year.index, grouped_new_year["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# Memorial Day: 29th May

# %%
data_md = data[data['start_time'].dt.date.astype(str) == '2017-05-29']
#data_md

# %%
grouped_md = data_md.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_md.index, grouped_md["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# # Independence Day

# %%
data_4th = data[data['start_time'].dt.date.astype(str) == '2017-02-20']
#data_4th

# %%
grouped_4th = data_4th.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_4th.index, grouped_4th["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# Labor Day: 4th Sep

# %%
data_ld = data[data['start_time'].dt.date.astype(str) == '2017-09-04']
#data_ld

# %%
grouped_ld = data_ld.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_ld.index, grouped_ld["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# Thanksgiving Day: 23rd Nov

# %%
data_tg = data[data['start_time'].dt.date.astype(str) == '2017-12-25']
#data_tg

# %%
grouped_tg = data_tg.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_tg.index, grouped_tg["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# Christmas Day: 25th Dec

# %%
data_christmas = data[data['start_time'].dt.date.astype(str) == '2017-12-25']
data_christmas
# Out:
#                  start_time            end_time dayofweek_start dayofweek_end  \
# 1311617 2017-12-25 00:06:25 2017-12-25 00:12:58          Monday        Monday
# 1311618 2017-12-25 00:10:08 2017-12-25 00:11:24          Monday        Monday
# 1311619 2017-12-25 00:34:24 2017-12-25 00:42:24          Monday        Monday
# 1311620 2017-12-25 00:55:57 2017-12-25 01:00:07          Monday        Monday
# 1311621 2017-12-25 01:00:50 2017-12-25 01:07:06          Monday        Monday
# ...                     ...                 ...             ...           ...
# 1311705 2017-12-25 22:34:50 2017-12-25 22:42:14          Monday        Monday
# 1311706 2017-12-25 23:01:15 2017-12-25 23:10:43          Monday        Monday
# 1311707 2017-12-25 23:04:25 2017-12-25 23:07:40          Monday        Monday
# 1311708 2017-12-25 23:17:13 2017-12-25 23:25:02          Monday        Monday
# 1311709 2017-12-25 23:32:24 2017-12-25 23:39:27          Monday        Monday
#
#         month_start month_end time_start  time_end  start_hour  \
# 1311617         Dec       Dec   00:06:25  00:12:58           0
# 1311618         Dec       Dec   00:10:08  00:11:24           0
# 1311619         Dec       Dec   00:34:24  00:42:24           0
# 1311620         Dec       Dec   00:55:57  01:00:07           0
# 1311621         Dec       Dec   01:00:50  01:07:06           1
# ...             ...       ...        ...       ...         ...
# 1311705         Dec       Dec   22:34:50  22:42:14          22
# 1311706         Dec       Dec   23:01:15  23:10:43          23
# 1311707         Dec       Dec   23:04:25  23:07:40          23
# 1311708         Dec       Dec   23:17:13  23:25:02          23
# 1311709         Dec       Dec   23:32:24  23:39:27          23
#
#                duration  duration_minutes
# 1311617 0 days 00:06:33          6.550000
# 1311618 0 days 00:01:16          1.266667
# 1311619 0 days 00:08:00          8.000000
# 1311620 0 days 00:04:10          4.166667
# 1311621 0 days 00:06:16          6.266667
# ...                 ...               ...
# 1311705 0 days 00:07:24          7.400000
# 1311706 0 days 00:09:28          9.466667
# 1311707 0 days 00:03:15          3.250000
# 1311708 0 days 00:07:49          7.816667
# 1311709 0 days 00:07:03          7.050000
#
# [93 rows x 11 columns]

# %%
grouped_christmas = data_christmas.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_christmas.index, grouped_christmas["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# Super Ball: 2nd Feb (Check if a major sport event has an impact)

# %%
data_supberball = data[data['start_time'].dt.date.astype(str) == '2017-02-05']
#data_supberball

# %%
grouped_SuperBall = data_supberball.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_SuperBall.index, grouped_SuperBall["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# # Check for any other / normal day in a week

# %%
data_common = data[data['start_time'].dt.date.astype(str) == '2017-06-14']
data_common
# Out:
#                 start_time            end_time dayofweek_start dayofweek_end  \
# 358621 2017-06-14 00:00:33 2017-06-14 00:09:32       Wednesday     Wednesday
# 358622 2017-06-14 00:00:40 2017-06-14 00:11:02       Wednesday     Wednesday
# 358623 2017-06-14 00:01:20 2017-06-14 00:06:13       Wednesday     Wednesday
# 358624 2017-06-14 00:08:48 2017-06-14 00:17:18       Wednesday     Wednesday
# 358625 2017-06-14 00:09:21 2017-06-14 00:21:08       Wednesday     Wednesday
# ...                    ...                 ...             ...           ...
# 365164 2017-06-14 23:52:59 2017-06-15 00:07:19       Wednesday      Thursday
# 365165 2017-06-14 23:55:10 2017-06-15 00:03:03       Wednesday      Thursday
# 365166 2017-06-14 23:55:16 2017-06-15 00:05:58       Wednesday      Thursday
# 365167 2017-06-14 23:55:21 2017-06-15 00:06:09       Wednesday      Thursday
# 365168 2017-06-14 23:57:52 2017-06-15 00:35:42       Wednesday      Thursday
#
#        month_start month_end time_start  time_end  start_hour        duration  \
# 358621         Jun       Jun   00:00:33  00:09:32           0 0 days 00:08:59
# 358622         Jun       Jun   00:00:40  00:11:02           0 0 days 00:10:22
# 358623         Jun       Jun   00:01:20  00:06:13           0 0 days 00:04:53
# 358624         Jun       Jun   00:08:48  00:17:18           0 0 days 00:08:30
# 358625         Jun       Jun   00:09:21  00:21:08           0 0 days 00:11:47
# ...            ...       ...        ...       ...         ...             ...
# 365164         Jun       Jun   23:52:59  00:07:19          23 0 days 00:14:20
# 365165         Jun       Jun   23:55:10  00:03:03          23 0 days 00:07:53
# 365166         Jun       Jun   23:55:16  00:05:58          23 0 days 00:10:42
# 365167         Jun       Jun   23:55:21  00:06:09          23 0 days 00:10:48
# 365168         Jun       Jun   23:57:52  00:35:42          23 0 days 00:37:50
#
#         duration_minutes
# 358621          8.983333
# 358622         10.366667
# 358623          4.883333
# 358624          8.500000
# 358625         11.783333
# ...                  ...
# 365164         14.333333
# 365165          7.883333
# 365166         10.700000
# 365167         10.800000
# 365168         37.833333
#
# [6548 rows x 11 columns]

# %%
grouped_common = data_common.groupby("start_hour")['month_start'].describe()
plt.bar(grouped_common.index, grouped_common["count"])

f = plt.gca()
f.axes.get_xaxis().set_visible(True)
plt.xlabel("Hour of day")
plt.ylabel("Number of Rides")
plt.title("Hourly Repartition")
# Out:
# Text(0.5, 1.0, 'Hourly Repartition')

# %% [markdown]
# # Week

# %%
data.groupby("dayofweek_start").describe()
# Out:
#                 start_hour                                                    \
#                      count       mean       std  min   25%   50%   75%   max
# dayofweek_start
# Friday            196327.0  13.431647  4.785872  0.0   9.0  14.0  17.0  23.0
# Monday            189512.0  13.695782  4.785923  0.0   9.0  15.0  17.0  23.0
# Saturday          153558.0  14.260566  4.615695  0.0  11.0  14.0  17.0  23.0
# Sunday            151515.0  14.083061  4.567267  0.0  11.0  14.0  17.0  23.0
# Thursday          210985.0  13.627694  4.883792  0.0   9.0  15.0  17.0  23.0
# Tuesday           203212.0  13.628393  4.820685  0.0   9.0  15.0  17.0  23.0
# Wednesday         208648.0  13.624832  4.834593  0.0   9.0  15.0  17.0  23.0
#
#                 duration                             ...                   \
#                    count                       mean  ...              75%
# dayofweek_start                                      ...
# Friday            196327  0 days 00:17:21.209507607  ...  0 days 00:17:01
# Monday            189512  0 days 00:17:29.975737684  ...  0 days 00:16:48
# Saturday          153558  0 days 00:27:34.142382682  ...  0 days 00:22:22
# Sunday            151515  0 days 00:24:57.472771672  ...  0 days 00:22:34
# Thursday          210985  0 days 00:16:02.816498803  ...  0 days 00:16:34
# Tuesday           203212  0 days 00:16:34.558948290  ...  0 days 00:16:36
# Wednesday         208648  0 days 00:16:05.366329895  ...  0 days 00:16:29
#
#                                   duration_minutes                         \
#                               max            count       mean         std
# dayofweek_start
# Friday           21 days 22:08:35         196327.0  17.353492  163.446995
# Monday           48 days 08:40:21         189512.0  17.499596  253.917263
# Saturday         34 days 01:02:48         153558.0  27.569040  313.933580
# Sunday           22 days 17:35:49         151515.0  24.957880  197.201024
# Thursday         34 days 10:43:17         210985.0  16.046942  200.935676
# Tuesday          33 days 00:13:20         203212.0  16.575982  197.459869
# Wednesday        28 days 03:46:11         208648.0  16.089439  186.340435
#
#
#                       min       25%        50%        75%           max
# dayofweek_start
# Friday           1.016667  6.450000  10.550000  17.016667  31568.583333
# Monday           1.016667  6.316667  10.383333  16.800000  69640.350000
# Saturday         1.016667  7.500000  13.416667  22.366667  49022.800000
# Sunday           1.016667  7.383333  13.283333  22.566667  32735.816667
# Thursday         1.016667  6.383333  10.366667  16.566667  49603.283333
# Tuesday          1.016667  6.366667  10.333333  16.600000  47533.333333
# Wednesday        1.016667  6.400000  10.350000  16.483333  40546.183333
#
# [7 rows x 24 columns]

# %%
grouped_by_weekday = data.groupby("dayofweek_start")['duration'].describe()
ax = grouped_by_weekday["count"].loc[day_order].plot(kind="bar", legend=False)
plt.xlabel("Day of the week")
plt.ylabel("Number of Rides")
plt.title("Rides per day of the week")
# Out:
# Text(0.5, 1.0, 'Rides per day of the week')

# %% [markdown]
# # Montly Reparition

# %%
data.groupby("month_start").describe()
# Out:
#             start_hour                                                    \
#                  count       mean       std  min   25%   50%   75%   max
# month_start
# Apr            99860.0  13.763259  4.680965  0.0  10.0  14.0  17.0  23.0
# Aug           190651.0  13.788084  4.777293  0.0  10.0  15.0  17.0  23.0
# Dec            55072.0  13.248293  4.833553  0.0   9.0  14.0  17.0  23.0
# Feb            17271.0  13.845406  4.691584  0.0  10.0  14.0  17.0  23.0
# Jan            19515.0  13.459185  4.731730  0.0   9.0  14.0  17.0  23.0
# Jul           175833.0  13.958785  4.835091  0.0  10.0  15.0  18.0  23.0
# Jun           161910.0  13.791205  4.805960  0.0   9.0  15.0  17.0  23.0
# Mar            31253.0  13.598503  4.738753  0.0   9.0  14.0  17.0  23.0
# May           127894.0  13.830586  4.757729  0.0  10.0  15.0  17.0  23.0
# Nov           105457.0  13.353215  4.809800  0.0   9.0  14.0  17.0  23.0
# Oct           163657.0  13.661585  4.749670  0.0   9.0  14.0  17.0  23.0
# Sep           165384.0  13.809788  4.744187  0.0  10.0  15.0  17.0  23.0
#
#             duration                             ...                   \
#                count                       mean  ...              75%
# month_start                                      ...
# Apr            99860  0 days 00:24:27.604626477  ...  0 days 00:19:10
# Aug           190651  0 days 00:18:42.644586181  ...  0 days 00:19:02
# Dec            55072  0 days 00:14:15.479063771  ...  0 days 00:14:26
# Feb            17271  0 days 00:11:21.410456835  ...  0 days 00:10:40
# Jan            19515  0 days 00:13:07.238431975  ...  0 days 00:11:35
# Jul           175833  0 days 00:21:42.852502090  ...  0 days 00:20:01
# Jun           161910  0 days 00:20:29.873491445  ...  0 days 00:19:04
# Mar            31253  0 days 00:15:50.992768694  ...  0 days 00:13:13
# May           127894  0 days 00:20:12.860556398  ...  0 days 00:17:51
# Nov           105457  0 days 00:14:09.106934579  ...  0 days 00:15:20
# Oct           163657  0 days 00:18:06.068319717  ...  0 days 00:17:23
# Sep           165384  0 days 00:17:42.937037440  ...  0 days 00:17:52
#
#                               duration_minutes                         \
#                           max            count       mean         std
# month_start
# Apr          48 days 08:40:21          99860.0  24.460077  428.839085
# Aug          22 days 00:31:38         190651.0  18.710743  138.097096
# Dec          33 days 00:13:20          55072.0  14.257984  245.378789
# Feb           1 days 23:40:10          17271.0  11.356841   44.634059
# Jan          11 days 03:10:14          19515.0  13.120641  131.459786
# Jul          30 days 05:19:54         175833.0  21.714208  221.067434
# Jun          24 days 19:31:05         161910.0  20.497892  182.667349
# Mar          13 days 22:06:23          31253.0  15.849879  197.110250
# May          34 days 10:43:17         127894.0  20.214343  268.792636
# Nov          16 days 17:47:43         105457.0  14.151782  104.857832
# Oct          28 days 03:46:11         163657.0  18.101139  209.615187
# Sep          21 days 22:08:35         165384.0  17.715617  149.558450
#
#
#                   min       25%        50%        75%           max
# month_start
# Apr          1.016667  6.616667  11.350000  19.166667  69640.350000
# Aug          1.016667  7.200000  11.916667  19.033333  31711.633333
# Dec          1.016667  5.800000   9.083333  14.433333  47533.333333
# Feb          1.050000  4.883333   6.916667  10.666667   2860.166667
# Jan          1.016667  5.083333   7.250000  11.583333  16030.233333
# Jul          1.016667  7.366667  12.333333  20.016667  43519.900000
# Jun          1.016667  7.204167  11.883333  19.066667  35731.083333
# Mar          1.016667  5.316667   8.133333  13.216667  20046.383333
# May          1.016667  6.566667  10.866667  17.850000  49603.283333
# Nov          1.016667  5.800000   9.450000  15.333333  24107.716667
# Oct          1.016667  6.400000  10.666667  17.383333  40546.183333
# Sep          1.016667  6.700000  11.083333  17.866667  31568.583333
#
# [12 rows x 24 columns]

# %%
grouped_by_month = data.groupby("month_start")['dayofweek_start'].describe()
ax = grouped_by_month["count"].loc[month_order].plot(kind="bar", legend=False)
plt.xlabel("Month")
plt.ylabel("Number of Rides")
# Out:
# Text(0, 0.5, 'Number of Rides')

# %% [markdown]
# # Trip durations

# %%
data_trip_duration = data[["dayofweek_start", "month_start", "start_hour", "duration_minutes"]]
data_trip_duration
# Out:
#         dayofweek_start month_start  start_hour  duration_minutes
# 0                Sunday         Jan           0          5.850000
# 1                Sunday         Jan           0         14.850000
# 2                Sunday         Jan           0         27.883333
# 3                Sunday         Jan           0         12.466667
# 4                Sunday         Jan           0         10.366667
# ...                 ...         ...         ...               ...
# 1313769          Sunday         Dec          23          4.150000
# 1313770          Friday         Dec          16          4.366667
# 1313771        Saturday         Dec           8         16.400000
# 1313772        Saturday         Dec          12         29.183333
# 1313773        Saturday         Dec          18         26.250000
#
# [1313757 rows x 4 columns]

# %% [markdown]
# # Average duration by starting hour

# %%
grouped_duration_hour = data.groupby("start_hour")['duration_minutes'].describe()
plt.bar(grouped_duration_hour.index, grouped_duration_hour["mean"])
f = plt.gca()
plt.xlabel("start hour")
plt.ylabel("Avg ride duration")
# Out:
# Text(0, 0.5, 'Avg ride duration')

# %% [markdown]
# # Average duration by weekdays

# %%
grouped_weekday_duration = data.groupby("dayofweek_start")["duration_minutes"].describe()
ax = grouped_weekday_duration["mean"].loc[day_order].plot(kind="bar")
plt.xlabel("Day of the week")
plt.ylabel("Avg duration")
# Out:
# Text(0, 0.5, 'Avg duration')

# %% [markdown]
# # Trip Length per month

# %%
grouped_month_duration = data.groupby("month_start")["duration_minutes"].describe()
ax = grouped_month_duration["mean"].loc[month_order].plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Avg duration")
# Out:
# Text(0, 0.5, 'Avg duration')
