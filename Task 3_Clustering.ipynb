# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Boston_Data_Clean.csv', index_col=0)
data.head()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#             start_time             end_time  start_station_id  end_station_id  \
# 0  2017-01-01 00:06:58  2017-01-01 00:12:49                67             139
# 1  2017-01-01 00:13:16  2017-01-01 00:28:07                36              10
# 2  2017-01-01 00:16:17  2017-01-01 00:44:10                36               9
# 3  2017-01-01 00:21:22  2017-01-01 00:33:50                46              19
# 4  2017-01-01 00:30:06  2017-01-01 00:40:28                10               8
#
#                          start_station_name  \
# 0              MIT at Mass Ave / Amherst St
# 1  Boston Public Library - 700 Boylston St.
# 2  Boston Public Library - 700 Boylston St.
# 3                   Christian Science Plaza
# 4             B.U. Central - 725 Comm. Ave.
#
# ...

# %% [markdown]
# # Data Prep and Scaling

# %%
data['start_time'] = pd.to_datetime(data['start_time'])
data['end_time'] = pd.to_datetime(data['end_time'])

# %%
# Trip length
delta = pd.DataFrame({'time_delta': data['end_time'] - data['start_time']})
delta
# Out:
#              time_delta
# 0       0 days 00:05:51
# 1       0 days 00:14:51
# 2       0 days 00:27:53
# 3       0 days 00:12:28
# 4       0 days 00:10:22
# ...                 ...
# 1313769 0 days 00:04:09
# 1313770 0 days 00:04:22
# 1313771 0 days 00:16:24
# 1313772 0 days 00:29:11
# 1313773 0 days 00:26:15
#
# [1313757 rows x 1 columns]

# %%
# Conversion into minutes
trip_length = delta['time_delta'].dt.components[['days', 'hours', 'minutes']]
trip_length_df = pd.DataFrame({'trip_length_min': trip_length['days'] * 24 * 60 + trip_length['hours'] * 60 + trip_length['minutes']})
trip_length_df
# Out:
#          trip_length_min
# 0                      5
# 1                     14
# 2                     27
# 3                     12
# 4                     10
# ...                  ...
# 1313769                4
# 1313770                4
# 1313771               16
# 1313772               29
# 1313773               26
#
# [1313757 rows x 1 columns]

# %%
# Join trip length to cleaned data
joined_data = data.join(trip_length_df, how='outer')
joined_data
# Out:
#                  start_time            end_time  start_station_id  \
# 0       2017-01-01 00:06:58 2017-01-01 00:12:49                67
# 1       2017-01-01 00:13:16 2017-01-01 00:28:07                36
# 2       2017-01-01 00:16:17 2017-01-01 00:44:10                36
# 3       2017-01-01 00:21:22 2017-01-01 00:33:50                46
# 4       2017-01-01 00:30:06 2017-01-01 00:40:28                10
# ...                     ...                 ...               ...
# 1313769 2017-12-31 23:46:18 2017-12-31 23:50:27               117
# 1313770 2017-12-29 16:11:56 2017-12-29 16:16:18                54
# 1313771 2017-12-30 08:09:44 2017-12-30 08:26:08                54
# 1313772 2017-12-30 12:20:01 2017-12-30 12:49:12                54
# 1313773 2017-12-30 18:27:39 2017-12-30 18:53:54                54
#
#          end_station_id                        start_station_name  \
# 0                   139              MIT at Mass Ave / Amherst St
# ...

# %%
date_info = pd.Series(data['start_time'])
date_info_df = pd.DataFrame({'month': date_info.dt.month, 'day_of_week': date_info.dt.day_of_week, 'start_time_minutes': 60 * date_info.dt.hour + date_info.dt.minute})
date_info_df
# Out:
#          month  day_of_week  start_time_minutes
# 0            1            6                   6
# 1            1            6                  13
# 2            1            6                  16
# 3            1            6                  21
# 4            1            6                  30
# ...        ...          ...                 ...
# 1313769     12            6                1426
# 1313770     12            4                 971
# 1313771     12            5                 489
# 1313772     12            5                 740
# 1313773     12            5                1107
#
# [1313757 rows x 3 columns]

# %%
# Add date information to data and drop start and end time
joined_data = joined_data.join([date_info_df], how='outer')
joined_data = joined_data.drop(['start_time', 'end_time'], axis=1)
joined_data
# Out:
#          start_station_id  end_station_id  \
# 0                      67             139
# 1                      36              10
# 2                      36               9
# 3                      46              19
# 4                      10               8
# ...                   ...             ...
# 1313769               117             141
# 1313770                54              42
# 1313771                54              58
# 1313772                54              46
# 1313773                54              21
#
#                                start_station_name  \
# 0                    MIT at Mass Ave / Amherst St
# 1        Boston Public Library - 700 Boylston St.
# 2        Boston Public Library - 700 Boylston St.
# 3                         Christian Science Plaza
# 4                   B.U. Central - 725 Comm. Ave.
# ...                                           ...
# 1313769                      Binney St / Sixth St
# ...

# %%
# User type is currently "subscriber" or "customer"
# Change to integer values
mapping = {'Subscriber': 1, 'Customer': 2}
joined_data = joined_data.replace({'user_type': mapping})
joined_data
# Out:
#          start_station_id  end_station_id  \
# 0                      67             139
# 1                      36              10
# 2                      36               9
# 3                      46              19
# 4                      10               8
# ...                   ...             ...
# 1313769               117             141
# 1313770                54              42
# 1313771                54              58
# 1313772                54              46
# 1313773                54              21
#
#                                start_station_name  \
# 0                    MIT at Mass Ave / Amherst St
# 1        Boston Public Library - 700 Boylston St.
# 2        Boston Public Library - 700 Boylston St.
# 3                         Christian Science Plaza
# 4                   B.U. Central - 725 Comm. Ave.
# ...                                           ...
# 1313769                      Binney St / Sixth St
# ...

# %%
#  Check if start and end location are the same
same_start_end = pd.DataFrame({'same_start_end': data['start_station_id'] == data['end_station_id']})
same_start_end
# Out:
#          same_start_end
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 1313769           False
# 1313770           False
# 1313771           False
# 1313772           False
# 1313773           False
#
# [1313757 rows x 1 columns]

# %%
# Add check column to data
joined_data = joined_data.drop(["start_station_id", "end_station_id", "bike_id", "start_station_name", "end_station_name"], axis=1)
joined_data = joined_data.join(pd.DataFrame(same_start_end), how='outer')
data = joined_data
data
# Out:
#          user_type  trip_length_min  month  day_of_week  start_time_minutes  \
# 0                1                5      1            6                   6
# 1                1               14      1            6                  13
# 2                2               27      1            6                  16
# 3                1               12      1            6                  21
# 4                1               10      1            6                  30
# ...            ...              ...    ...          ...                 ...
# 1313769          1                4     12            6                1426
# 1313770          1                4     12            4                 971
# 1313771          1               16     12            5                 489
# 1313772          1               29     12            5                 740
# 1313773          1               26     12            5                1107
#
#          same_start_end
# 0                 False
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data)
data_scaled = scaler.transform(data)
data_scaled_df = pd.DataFrame(data_scaled, columns=data.columns, index=data.index)
data_scaled_df.head()
# Out:
#    user_type  trip_length_min     month  day_of_week  start_time_minutes  \
# 0  -0.434985        -0.061692 -2.594331     1.648628           -2.961556
# 1  -0.434985        -0.020329 -2.594331     1.648628           -2.937093
# 2   2.298929         0.039417 -2.594331     1.648628           -2.926609
# 3  -0.434985        -0.029521 -2.594331     1.648628           -2.909135
# 4  -0.434985        -0.038713 -2.594331     1.648628           -2.877683
#
#    same_start_end
# 0       -0.179418
# 1       -0.179418
# 2       -0.179418
# 3       -0.179418
# 4       -0.179418

# %%
user_scaled = data_scaled_df
user_scaled["user_type"] = data["user_type"]

# %%
user_scaled
# Out:
#          user_type  trip_length_min     month  day_of_week  \
# 0                1        -0.061692 -2.594331     1.648628
# 1                1        -0.020329 -2.594331     1.648628
# 2                2         0.039417 -2.594331     1.648628
# 3                1        -0.029521 -2.594331     1.648628
# 4                1        -0.038713 -2.594331     1.648628
# ...            ...              ...       ...          ...
# 1313769          1        -0.066288  1.792498     1.648628
# 1313770          1        -0.066288  1.792498     0.609053
# 1313771          1        -0.011138  1.792498     1.128840
# 1313772          1         0.048609  1.792498     1.128840
# 1313773          1         0.034821  1.792498     1.128840
#
#          start_time_minutes  same_start_end
# 0                 -2.961556       -0.179418
# 1                 -2.937093       -0.179418
# 2                 -2.926609       -0.179418
# 3                 -2.909135       -0.179418
# ...

# %%
# Takes about 15 minutes to run
sns.pairplot(data=data_scaled_df, hue="user_type")

# %%
from sklearn.cluster import KMeans

# %%
k_max = 15

# %%
# k_max = 10 About 2-3 minutes
# k_max = 20 About 17 minutes
clusters = []
losses = []

for k in range(k_max):
    model = KMeans(n_clusters= k + 1)
    model.fit(data_scaled)
    clusters.append(k + 1)
    losses.append(model.inertia_)

# %%
plt.plot(clusters, losses)
plt.ylabel("Loss")
plt.xlabel("Number of clusters")
plt.show()

# %%
# Zoom in
plt.plot(clusters, losses)
plt.ylabel("Loss")
plt.xlabel("Number of clusters")
plt.xlim([0,10])
# Out:
# (0.0, 10.0)

# %%
two_means = KMeans(n_clusters=2)
two_means.fit(data_scaled)

two_means.predict(data_scaled)
data_scaled
# Out:
# array([[-0.43498507, -0.06169227, -2.5943313 ,  1.64862751, -2.96155559,
#         -0.17941802],
#        [-0.43498507, -0.0203293 , -2.5943313 ,  1.64862751, -2.93709273,
#         -0.17941802],
#        [ 2.29892946,  0.0394172 , -2.5943313 ,  1.64862751, -2.92660865,
#         -0.17941802],
#        ...,
#        [-0.43498507, -0.01113754,  1.79249775,  1.12884047, -1.27361838,
#         -0.17941802],
#        [-0.43498507,  0.04860897,  1.79249775,  1.12884047, -0.39645018,
#         -0.17941802],
#        [-0.43498507,  0.03482131,  1.79249775,  1.12884047,  0.88610252,
#         -0.17941802]])

# %%
numbers = ["zero", "one", "two"]

user_scaled["two"] = two_means.predict(user_scaled)
user_scaled["two"] = user_scaled["two"].apply(lambda x: numbers[x])
sns.pairplot(data=user_scaled, hue="two")

# %%
user_scaled
# Out:
#          user_type  trip_length_min     month  day_of_week  \
# 0                1        -0.061692 -2.594331     1.648628
# 1                1        -0.020329 -2.594331     1.648628
# 2                2         0.039417 -2.594331     1.648628
# 3                1        -0.029521 -2.594331     1.648628
# 4                1        -0.038713 -2.594331     1.648628
# ...            ...              ...       ...          ...
# 1313769          1        -0.066288  1.792498     1.648628
# 1313770          1        -0.066288  1.792498     0.609053
# 1313771          1        -0.011138  1.792498     1.128840
# 1313772          1         0.048609  1.792498     1.128840
# 1313773          1         0.034821  1.792498     1.128840
#
#          start_time_minutes  same_start_end   two
# 0                 -2.961556       -0.179418  zero
# 1                 -2.937093       -0.179418  zero
# 2                 -2.926609       -0.179418  zero
# 3                 -2.909135       -0.179418  zero
# ...

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1)
data_pca = pca.fit_transform(data_scaled)

# %%
pca.components_
# Out:
# array([[ 0.6439821 ,  0.1881152 , -0.20777663,  0.49966032,  0.19183364,
#          0.46932719]])

# %%
print(pca.explained_variance_ratio_[0])
# Out:
# 0.22196527969735233

# %%
pca2 = PCA(n_components=2)
data_pca2 = pca2.fit_transform(data_scaled)

# %%
print(pca2.explained_variance_ratio_)
print(sum(pca2.explained_variance_ratio_))
# Out:
# [0.22196528 0.16750963]
# 0.3894749104484492

# %%
pca3 = PCA(n_components=3)
data_pca3 = pca3.fit_transform(data_scaled)
print(pca3.explained_variance_ratio_)
print(sum(pca3.explained_variance_ratio_))
# Out:
# [0.22196528 0.16750963 0.16469421]
# 0.5541691181178758

# %%
pca4 = PCA(n_components=4)
data_pca4 = pca4.fit_transform(data_scaled)
print(pca4.explained_variance_ratio_)
print(sum(pca4.explained_variance_ratio_))
# Out:
# [0.22196528 0.16750963 0.16469421 0.16321181]
# 0.7173809248268728

# %%
pca5 = PCA(n_components=5)
data_pca5 = pca5.fit_transform(data_scaled)
print(pca5.explained_variance_ratio_)
print(sum(pca5.explained_variance_ratio_))
# Out:
# [0.22196528 0.16750963 0.16469421 0.16321181 0.15579769]
# 0.8731786123409605

# %% [markdown]
# PCA not worth it. When reducing the dimensions by one, only 87% of the original variance is left in the dataset.
# Should be at least 95%.

# %%
mapping_cluster_number = {0: "zero", 1: "one"}

# %%
def print_avergae_weekday(cluster_i, i):
    print("In cluster {0} the average day of the week the bike is rented is  {1}.".format(
        i,  cluster_i.describe()['day_of_week']['mean']))

# %%
i = 0
cluster_i = user_scaled[user_scaled["two"] == mapping_cluster_number.get(i)]
print_avergae_weekday(cluster_i, i)
# Out:
# In cluster 0 the average day of the week the bike is rented is  0.7268932921327999.

# %%
joined_data
# Out:
#          user_type  trip_length_min  month  day_of_week  start_time_minutes  \
# 0                1                5      1            6                   6
# 1                1               14      1            6                  13
# 2                2               27      1            6                  16
# 3                1               12      1            6                  21
# 4                1               10      1            6                  30
# ...            ...              ...    ...          ...                 ...
# 1313769          1                4     12            6                1426
# 1313770          1                4     12            4                 971
# 1313771          1               16     12            5                 489
# 1313772          1               29     12            5                 740
# 1313773          1               26     12            5                1107
#
#          same_start_end
# 0                 False
# ...

# %%
mapping_cluster_number = {0: "zero", 1: "one"}

# %%
def print_avergae_weekday(cluster_i, i):
    print("In cluster {0} the average day of the week the bike is rented is  {1}.".format(
        i,  cluster_i.describe()['day_of_week']['mean']))

# %%
i = 0
cluster_i = joined_data[joined_data["two"] == mapping_cluster_number.get(i)]
print_avergae_weekday(cluster_i, i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'two'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
n_means = KMeans(n_clusters=2)
n_means.fit(joined_data)

n_means.predict(joined_data)
joined_data
# Out:
#          user_type  trip_length_min  month  day_of_week  start_time_minutes  \
# 0                1                5      1            6                   6
# 1                1               14      1            6                  13
# 2                2               27      1            6                  16
# 3                1               12      1            6                  21
# 4                1               10      1            6                  30
# ...            ...              ...    ...          ...                 ...
# 1313769          1                4     12            6                1426
# 1313770          1                4     12            4                 971
# 1313771          1               16     12            5                 489
# 1313772          1               29     12            5                 740
# 1313773          1               26     12            5                1107
#
#          same_start_end
# 0                 False
# ...

# %%
numbers = ["zero", "one"]

joined_data["cluster"] = n_means.predict(joined_data)
joined_data["cluster"] = joined_data["cluster"].apply(lambda x: numbers[x])
joined_data
# Out:
#          user_type  trip_length_min  month  day_of_week  start_time_minutes  \
# 0                1                5      1            6                   6
# 1                1               14      1            6                  13
# 2                2               27      1            6                  16
# 3                1               12      1            6                  21
# 4                1               10      1            6                  30
# ...            ...              ...    ...          ...                 ...
# 1313769          1                4     12            6                1426
# 1313770          1                4     12            4                 971
# 1313771          1               16     12            5                 489
# 1313772          1               29     12            5                 740
# 1313773          1               26     12            5                1107
#
#          same_start_end cluster
# ...

# %%
mapping_cluster_number = {0: "zero", 1: "one"}

# %%
def print_avergae_start_time(cluster_i, i):
    avg_start_min = cluster_i.describe()['start_time_minutes']['mean']
    hour = int(avg_start_min // 60)
    minutes = int(avg_start_min % 60)
    print("In cluster {0} the average start time is {1}:{2}.".format(i, hour, minutes))

# %%
i = 0
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_avergae_start_time(cluster_i, i)
i = 1
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_avergae_start_time(cluster_i, i)
# Out:
# In cluster 0 the average start time is 17:46.
# In cluster 1 the average start time is 9:31.

# %%
def print_number_instances(cluster_i, i):
    print("In cluster {0} we have {1} number of instances assigned.".format(i, cluster_i.describe()['user_type']['count']))

# %%
i = 0
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_number_instances(cluster_i, i)
i = 1
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_number_instances(cluster_i, i)
# Out:
# In cluster 0 we have 748951.0 number of instances assigned.
# In cluster 1 we have 564806.0 number of instances assigned.

# %%
def print_avergae_weekday(cluster_i, i):
    print("In cluster {0} the average day of the week the bike is rented is  {1}.".format(i,  cluster_i.describe()['day_of_week']['mean']))

# %%
i = 0
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_avergae_weekday(cluster_i, i)
i = 1
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_avergae_weekday(cluster_i, i)
# Out:
# In cluster 0 the average day of the week the bike is rented is  2.871741943064366.
# In cluster 1 the average day of the week the bike is rented is  2.7706097314830225.

# %%
def print_average_month(cluster_i, i):
    print("In cluster {0}  the average month the bike is rented is {1}.".format(i,  cluster_i.describe()['month']['mean']))

# %%
i = 0
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_average_month(cluster_i, i)
i = 1
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_average_month(cluster_i, i)
# Out:
# In cluster 0  the average month the bike is rented is 7.476506473721245.
# In cluster 1  the average month the bike is rented is 7.543483957323399.

# %%
def print_avergae_trip_lenght(cluster_i, i):
    print("In cluster {0}  the average trip length is {1} minutes.".format(
        i,  cluster_i.describe()['trip_length_min']['mean']))

# %%
i = 0
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_avergae_trip_lenght(cluster_i, i)
i = 1
cluster_i = joined_data[joined_data["cluster"] == mapping_cluster_number.get(i)]
print_avergae_trip_lenght(cluster_i, i)
# Out:
# In cluster 0  the average trip length is 19.282354920415354 minutes.
# In cluster 1  the average trip length is 17.28433125710421 minutes.
