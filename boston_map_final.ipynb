# %% [markdown]
# # Boston Interactive Map

# %% [markdown]
# The following code is used to show an Interactive Location Map with all the Blubikes stations in Boston. In particular, I used the original Bluebikes data regarding the Bluebikes stations, from which I have eliminated all the stations whose deployment year was higher than 2017. Finally, from this data I obtained an interactive map with all the Blubikes stations in Boston.

# %%
import folium
import pandas as pd

# %%
#import data for markers
data = pd.read_csv("current_bluebikes_stations.csv", header=1)
df = data[data['Deployment Year'] <= 2017]
df
# Out:
#      Number                                               Name   Latitude  \
# 2    A32019                                   175 N Harvard St  42.363796
# 6    M32026          359 Broadway - Broadway at Fayette Street  42.370803
# 22   A32032            Airport T Stop - Bremen St at Brooks St  42.374103
# 24   M32046                        Alewife MBTA at Steel Place  42.395588
# 25   M32033                   Alewife Station at Russell Field  42.396105
# ..      ...                                                ...        ...
# 435  D32002                        Washington St at Waltham St  42.341575
# 436  C32034  Watermark Seaport - Boston Wharf Rd at Seaport...  42.351586
# 441  B32021  Wentworth Institute of Technology - Huntington...  42.337586
# 442  D32022                                      West End Park  42.365908
# 447  S32005                                      Wilson Square  42.385676
#
#      Longitude    District Public  Total docks  Deployment Year
# ...

# %%
#basemap

map = folium.Map(location = [42.3601,-71.0589], zoom_start = 13)

#add markers
for Name, Longitude, Latitude in zip(df['Name'],df['Longitude'],df['Latitude']):
    folium.Marker(location = [Latitude, Longitude], popup = Name).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
